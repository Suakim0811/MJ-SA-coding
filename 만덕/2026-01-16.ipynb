# %%
# 1085

r = list(map(int, input().split()))
t1 = abs(r[0])
t2 = abs(r[2] - r[0])
t3 = abs(r[1])
t4 = abs(r[-1] - r[1])
b = [t1, t2, t3, t4]
print(min(b))
if 3*r[0] == 10*r[1]:
    v = (r[0]**2 + r[1]**2)**(1//2)
    t = ((r[0]-r[-2])**2 + (r[1]-r[-1])**2)**(1//2)
    b = [t1, t2, t3, t4, v, t]
    print(min(b))
if -3*r[0] + 10 == 10*r[1]:
    v = ((r[0]-r[-2])**2 + (r[1])**2)**(1//2)
    t = ((r[0])**2 + (r[1]-r[-1])**2)**(1//2)
    b = [t1, t2, t3, t4, v, t]
    print(min(b))
# Out:
# 161

# %%
# 2523
star = int(input())
for i in range(1, star+1):
    a = '*'*(i)
    print(a)
for t in range(star-1, 0, -1):
    print('*'*t)
# Out:
# *
# **
# ***
# **
# *

# %%
#2863

a,b,c,d = list(map(int,input().split()))
t = [a/c + b/d, c/d + a/b, d/b + c/a, b/a + d/c]
b = max(t)
for i in range(len(t)):
    if t[i] == b:
        print(i)

        #if t[i]==t[i-1] or t[i]==t[i-2] or t[i] == t[i-3]:
# Out:
# 2

# %%
# 3034

l = list(map(int, input().split()))
n, w, h = l[0], l[1], l[2]
for i in range(3):
    x = l.pop(i*0)
for a in l:
    if a<=w and a<=h or a<=(w**2+h**2)**(1/2):
        print('DA')
    else:
        print('NE')
# Out:
# NE
# DA

# %%
# 4504
l = list(map(int, input().split()))
t = l[0]
x = l.pop(0)
for i in l:
    if i == 0:
        break
    if i%t == 0:
        print(f'{i} is a multiple of {t}.')
    else:
        print(f'{i} is NOT a multiple of {t}.')
# Out:
# 1 is NOT a multiple of 3.
# 7 is NOT a multiple of 3.
# 99 is a multiple of 3.
# 321 is a multiple of 3.
# 777 is a multiple of 3.

# %%
# 4766
tem = list(map(float, input().split()))
x = tem.pop(-1)
for i in range(1, len(tem)):
    print(round(tem[i]-tem[i-1], 2))
# Out:
# 2.05
# 18.2
# -10.25

# %%
# 2444
num = int(input())
for i in range(num):
    s = '*'*(2*i + 1)
    b = ' '*(num - i -1)
    print(b+s)
for u in range(num-1, -1, -1):
    s = '*'*(2*(u-1)+1)
    b = ' '*(num - u)
    print(b+s)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
#  *********
#   *******
#    *****
#     ***
#      *

# %%
# 2522
num = int(input())
for i in range(num):
    print(' '*(num-i-1)+'*'*(i+1))
for u in range(num-1):
    print(' '*(u+1)+'*'*(num - u -1))
# Out:
#   *
#  **
# ***
#  **
#   *

# %%
# 5724

n = list(map(int, input().split()))
x = n.pop(-1)
v = []
for i in n:
    for k in range(i+1):
        s = k*k
        x = v.append(s)
    print(sum(v))
    x = v.clear()


while True:
    n = int(input())
    if n == 0:
        break

    total = 0
    for i in range(1, n+1):
        total += i*i

    print(total)

# %%
t = 0
for i in range(3):
    t -= 1 + i   #t에 이전에 계산한 값을 누적 시키는 것 +=, -=는 반대로 누적해서 뺌
    print(t)
# Out:
# -1
# -3
# -6

# %%
# 10103
dice = list(map(int, input().split()))
chang = 100
sang = 100
for i in range(len(dice)):
    if i%2 != 0 and i != 0 :
        if dice[i] > dice[i+1]:
            sang -= dice[i]
        if dice[i]<dice[i+1]:
            chang -= dice[i+1]
    if i%2 ==0 :
        continue
print(chang)
print(sang)
# Out:
# 94
# 91
